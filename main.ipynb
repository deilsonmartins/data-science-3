# %% [markdown]
# # Desafio 5
#
# Neste desafio, vamos praticar sobre redução de dimensionalidade com PCA e seleção de variáveis com RFE. Utilizaremos o _data set_ [Fifa 2019](https://www.kaggle.com/karangadiya/fifa19), contendo originalmente 89 variáveis de mais de 18 mil jogadores do _game_ FIFA 2019.
#
# > Obs.: Por favor, não modifique o nome das funções de resposta.

# %% [markdown]
# ## _Setup_ geral

# %%
from math import sqrt

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as sct
import seaborn as sns
import statsmodels.api as sm
import statsmodels.stats as st
from sklearn.decomposition import PCA
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#!pip install loguru
from loguru import logger
# Out:
# Collecting loguru
#   Downloading https://files.pythonhosted.org/packages/59/4f/baee593c195cd4b56cf008c9473347f3b0795b47d3b946e03706a8b43fca/loguru-0.5.1-py3-none-any.whl (56kB)
#      |████████████████████████████████| 61kB 1.7MB/s
# Collecting aiocontextvars>=0.2.0; python_version < "3.7"
#   Downloading https://files.pythonhosted.org/packages/db/c1/7a723e8d988de0a2e623927396e54b6831b68cb80dce468c945b849a9385/aiocontextvars-0.2.2-py2.py3-none-any.whl
# Collecting contextvars==2.4; python_version < "3.7"
#   Downloading https://files.pythonhosted.org/packages/83/96/55b82d9f13763be9d672622e1b8106c85acb83edd7cc2fa5bc67cd9877e9/contextvars-2.4.tar.gz
# Collecting immutables>=0.9
#   Downloading https://files.pythonhosted.org/packages/99/e0/ea6fd4697120327d26773b5a84853f897a68e33d3f9376b00a8ff96e4f63/immutables-0.14-cp36-cp36m-manylinux1_x86_64.whl (98kB)
#      |████████████████████████████████| 102kB 4.6MB/s
# Building wheels for collected packages: contextvars
#   Building wheel for contextvars (setup.py) ... done
#   Created wheel for contextvars: filename=contextvars-2.4-cp36-none-any.whl size=7666 sha256=21c03cd21a201a2ad38e3092f61ea21ac246dd2ac811b2ea37bf7f38fdb6cc06
#   Stored in directory: /root/.cache/pip/wheels/a5/7d/68/1ebae2668bda2228686e3c1cf16f2c2384cea6e9334ad5f6de
# Successfully built contextvars
# Installing collected packages: immutables, contextvars, aiocontextvars, loguru
# Successfully installed aiocontextvars-0.2.2 contextvars-2.4 immutables-0.14 loguru-0.5.1

# %%
# Algumas configurações para o matplotlib.
#%matplotlib inline

#from IPython.core.pylabtools import figsize


#figsize(12, 8)

#sns.set()

# %%
fifa = pd.read_csv("fifa.csv")

# %%
columns_to_drop = ["Unnamed: 0", "ID", "Name", "Photo", "Nationality", "Flag",
                   "Club", "Club Logo", "Value", "Wage", "Special", "Preferred Foot",
                   "International Reputation", "Weak Foot", "Skill Moves", "Work Rate",
                   "Body Type", "Real Face", "Position", "Jersey Number", "Joined",
                   "Loaned From", "Contract Valid Until", "Height", "Weight", "LS",
                   "ST", "RS", "LW", "LF", "CF", "RF", "RW", "LAM", "CAM", "RAM", "LM",
                   "LCM", "CM", "RCM", "RM", "LWB", "LDM", "CDM", "RDM", "RWB", "LB", "LCB",
                   "CB", "RCB", "RB", "Release Clause"
]

try:
    fifa.drop(columns_to_drop, axis=1, inplace=True)
except KeyError:
    logger.warning(f"Columns already dropped")

# %% [markdown]
# ## Inicia sua análise a partir daqui

# %%
# Sua análise começa aqui.
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 37 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              18207 non-null  int64
#  1   Overall          18207 non-null  int64
#  2   Potential        18207 non-null  int64
#  3   Crossing         18159 non-null  float64
#  4   Finishing        18159 non-null  float64
#  5   HeadingAccuracy  18159 non-null  float64
#  6   ShortPassing     18159 non-null  float64
#  7   Volleys          18159 non-null  float64
#  8   Dribbling        18159 non-null  float64
#  9   Curve            18159 non-null  float64
#  10  FKAccuracy       18159 non-null  float64
#  11  LongPassing      18159 non-null  float64
#  12  BallControl      18159 non-null  float64
#  13  Acceleration     18159 non-null  float64
#  14  SprintSpeed      18159 non-null  float64
#  15  Agility          18159 non-null  float64
#  16  Reactions        18159 non-null  float64
#  17  Balance          18159 non-null  float64
#  18  ShotPower        18159 non-null  float64
#  19  Jumping          18159 non-null  float64
#  20  Stamina          18159 non-null  float64
#  21  Strength         18159 non-null  float64
#  22  LongShots        18159 non-null  float64
#  23  Aggression       18159 non-null  float64
#  24  Interceptions    18159 non-null  float64
#  25  Positioning      18159 non-null  float64
#  26  Vision           18159 non-null  float64
#  27  Penalties        18159 non-null  float64
#  28  Composure        18159 non-null  float64
#  29  Marking          18159 non-null  float64
#  30  StandingTackle   18159 non-null  float64
#  31  SlidingTackle    18159 non-null  float64
#  32  GKDiving         18159 non-null  float64
#  33  GKHandling       18159 non-null  float64
#  34  GKKicking        18159 non-null  float64
#  35  GKPositioning    18159 non-null  float64
#  36  GKReflexes       18159 non-null  float64
# dtypes: float64(34), int64(3)
# memory usage: 5.1 MB

# %%
fifa.isna().sum()
# Out:
# Age                 0
# Overall             0
# Potential           0
# Crossing           48
# Finishing          48
# HeadingAccuracy    48
# ShortPassing       48
# Volleys            48
# Dribbling          48
# Curve              48
# FKAccuracy         48
# LongPassing        48
# BallControl        48
# Acceleration       48
# SprintSpeed        48
# Agility            48
# Reactions          48
# Balance            48
# ShotPower          48
# Jumping            48
# Stamina            48
# Strength           48
# LongShots          48
# Aggression         48
# Interceptions      48
# Positioning        48
# Vision             48
# Penalties          48
# Composure          48
# Marking            48
# StandingTackle     48
# SlidingTackle      48
# GKDiving           48
# GKHandling         48
# GKKicking          48
# GKPositioning      48
# GKReflexes         48
# dtype: int64

# %%
fifa.dropna(inplace=True)
fifa.isna().sum()
# Out:
# Age                0
# Overall            0
# Potential          0
# Crossing           0
# Finishing          0
# HeadingAccuracy    0
# ShortPassing       0
# Volleys            0
# Dribbling          0
# Curve              0
# FKAccuracy         0
# LongPassing        0
# BallControl        0
# Acceleration       0
# SprintSpeed        0
# Agility            0
# Reactions          0
# Balance            0
# ShotPower          0
# Jumping            0
# Stamina            0
# Strength           0
# LongShots          0
# Aggression         0
# Interceptions      0
# Positioning        0
# Vision             0
# Penalties          0
# Composure          0
# Marking            0
# StandingTackle     0
# SlidingTackle      0
# GKDiving           0
# GKHandling         0
# GKKicking          0
# GKPositioning      0
# GKReflexes         0
# dtype: int64

# %%
corr = fifa.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col1 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col3 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col4 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col5 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col6 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col7 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col8 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col9 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col10 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col11 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col12 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col13 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col14 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col15 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col16 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col17 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col18 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col19 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col20 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col21 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col22 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col23 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col24 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col25 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col26 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col27 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col28 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col29 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col30 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col31 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col32 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col33 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col34 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col35 {
#             background-color:  #dedcdb;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row0_col36 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row1_col0 {
#             background-color:  #ecd3c5;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row1_col2 {
#             background-color:  #f6a283;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row1_col3 {
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row1_col4 {
#             background-color:  #efcfbf;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row1_col5 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row1_col6 {
#             background-color:  #f7a889;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row1_col7 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row1_col8 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row1_col9 {
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row1_col10 {
#             background-color:  #f3c8b2;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row1_col11 {
#             background-color:  #f7b497;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row1_col12 {
#             background-color:  #f7ad90;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row1_col13 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row1_col14 {
#             background-color:  #dedcdb;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row1_col15 {
#             background-color:  #e1dad6;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row1_col16 {
#             background-color:  #e26952;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row1_col17 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row1_col18 {
#             background-color:  #f7b99e;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row1_col19 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row1_col20 {
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row1_col21 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }    #T_5c2a1988_c5fd_11ea_9623_0242ac1c0002row1_col22 {
#             background-color:  #

# %%
fifa.shape
# Out:
# (18159, 37)

# %% [markdown]
# ## Questão 1
#
# Qual fração da variância consegue ser explicada pelo primeiro componente principal de `fifa`? Responda como um único float (entre 0 e 1) arredondado para três casas decimais.

# %%
def q1():
    # Retorne aqui o resultado da questão 1.
    pca = PCA()

    var= pca.fit(fifa)
    
    return float(round(var.explained_variance_ratio_[0], 3))

q1()
# Out:
# 0.565

# %% [markdown]
# ## Questão 2
#
# Quantos componentes principais precisamos para explicar 95% da variância total? Responda como un único escalar inteiro.

# %%
def q2():
    # Retorne aqui o resultado da questão 2.
    pca = PCA().fit(fifa)

    cumulative_variance_ratio = np.cumsum(pca.explained_variance_ratio_)
    
    component_number = np.argmax(cumulative_variance_ratio >= 0.95) + 1 # Contagem começa em zero.

    #g = sns.lineplot(np.arange(len(evr)), np.cumsum(evr))
    #g.axes.axhline(0.95, ls="--", color="red")
    #plt.xlabel('Number of components')
    #plt.ylabel('Cumulative explained variance');

    return int(component_number)

q2()
# Out:
# 15

# %% [markdown]
# ## Questão 3
#
# Qual são as coordenadas (primeiro e segundo componentes principais) do ponto `x` abaixo? O vetor abaixo já está centralizado. Cuidado para __não__ centralizar o vetor novamente (por exemplo, invocando `PCA.transform()` nele). Responda como uma tupla de float arredondados para três casas decimais.

# %%
x = [0.87747123,  -1.24990363,  -1.3191255, -36.7341814,
     -35.55091139, -37.29814417, -28.68671182, -30.90902583,
     -42.37100061, -32.17082438, -28.86315326, -22.71193348,
     -38.36945867, -20.61407566, -22.72696734, -25.50360703,
     2.16339005, -27.96657305, -33.46004736,  -5.08943224,
     -30.21994603,   3.68803348, -36.10997302, -30.86899058,
     -22.69827634, -37.95847789, -22.40090313, -30.54859849,
     -26.64827358, -19.28162344, -34.69783578, -34.6614351,
     48.38377664,  47.60840355,  45.76793876,  44.61110193,
     49.28911284
]

# %%
def q3():
    # Retorne aqui o resultado da questão 3.
    pca = PCA().fit(fifa)
  
    coord1 = pca.components_.dot(x)[0].round(3)

    coord2 = pca.components_.dot(x)[1].round(3)

    return (float(coord1), float(coord2))

q3()
# Out:
# (186.556, -6.592)

# %% [markdown]
# ## Questão 4
#
# Realiza RFE com estimador de regressão linear para selecionar cinco variáveis, eliminando uma a uma. Quais são as variáveis selecionadas? Responda como uma lista de nomes de variáveis.

# %%
#!pip install sklearn
# Out:
# Requirement already satisfied: sklearn in /usr/local/lib/python3.6/dist-packages (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from sklearn) (0.22.2.post1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.18.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (0.16.0)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.4.1)

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

def q4():
    # Retorne aqui o resultado da questão 4.
    X = fifa.drop(['Overall'], axis=1)

    y = fifa['Overall']

    estimator = LinearRegression()

    selector = RFE(estimator, n_features_to_select=5, step=1)

    selector.fit(X, y)

    return list(X.columns[selector.support_])

q4()
# Out:
# ['Age', 'Potential', 'BallControl', 'Reactions', 'GKReflexes']
